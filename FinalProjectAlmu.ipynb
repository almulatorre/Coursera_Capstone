# %% [markdown]
# ## **FINAL PROJECT** By Almu
#
# **INVESTMENT IN MADRID OR BARCELONA**
# RICS’ Global Commercial Property Monitor is a quarterly guide to the trends in the commercial property investment and occupier markets.
# Last September, the Iberian Commercial Property Monitor index was published by RICS, and it shows Madrid and Barcelona are the best places in Europe to invest, next to Amsterdam and Budapest.
# The objective of this analysis is to help investors, who want to invest in Spain, decide which city, Madrid or Barcelona, has the best opportunities.
#
# **DATA**
# In this analysis, we use the Foursquare API to obtain location data of hotels, both in Madrid, and Barcelona, and we compare the results, so that we can find any gap in the hotels distribution which turns into an investment opportunity.

# %% [markdown]
# **Let's take the data via Foursquare API for Hotels in Madrid downtown.**

# %%
import requests
import pandas as pd 
from pandas.io.json import json_normalize

# %%
CLIENT_ID = '2SRL1KRLKMDOPB53MA30O0BCKNEZFBPHNTAAKKYJD1RCI0IH' # your Foursquare ID
CLIENT_SECRET = '4XFUL1KQVXEFRO0V04XKXYUKKYBCAGIWWJQ1G4Y5C30EGNMH' # your Foursquare Secret
#city: Madrid
latitude = 40.40841191
longitude = -3.68760088

VERSION = '20180604'
search_query = 'Hotel'
radius = 2000
LIMIT = 100

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2SRL1KRLKMDOPB53MA30O0BCKNEZFBPHNTAAKKYJD1RCI0IH&client_secret=4XFUL1KQVXEFRO0V04XKXYUKKYBCAGIWWJQ1G4Y5C30EGNMH&ll=40.40841191,-3.68760088&v=20180604&query=Hotel&radius=2000&limit=100'

# %%
results = requests.get(url).json()

# %%
venues = results['response']['venues']
df = json_normalize(venues)
df.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id                               location.address  \
# 0  4adcda33f964a520733a21e3                           P. Reina Cristina, 7
# 1  4c2dfdff987f20a108504aaa                                C/ Delicias, 42
# 2  4bcf378e9854d13a2da1f54d                        Paseo de la Delicias 26
# 3  4bd1c3db046076b07d657271                             Calle de Atocha 83
# 4  4bc83f6992b376b04f08513a  Calle Moratín 53, Plaza de Platerias Martinez
#
#   location.cc location.city location.country location.crossStreet  \
# 0          ES        Madrid           España                  NaN
# 1          ES        Madrid           España                  NaN
# 2          ES        Madrid           España                  NaN
# 3          ES        Madrid           España                  NaN
# 4          ES        Madrid           España                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                417  [P. Reina Cristina, 7, 28014 Madrid Madrid, Es...
# 1                554     [C/ Delicias, 42, 28045 Madrid Madrid, España]
# 2                633  [Paseo de la Delicias 26, 28045 Madrid Madrid,...
# 3                917  [Calle de Atocha 83, 28012 Madrid Madrid, España]
# 4                720  [Calle Moratín 53, Plaza de Platerias Martinez...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.40685544871869...     40.406855
# 1  [{'label': 'display', 'lat': 40.40377260592507...     40.403773
# 2  [{'label': 'display', 'lat': 40.40512283020258...     40.405123
# 3  [{'label': 'display', 'lat': 40.4116908, 'lng'...     40.411691
# 4  [{'label': 'display', 'lat': 40.41251660565832...     40.412517
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     -3.683119                   NaN               28014         Madrid
# 1     -3.689994                   NaN               28045         Madrid
# 2     -3.693702                   NaN               28045         Madrid
# 3     -3.697533                   NaN               28012         Madrid
# 4     -3.694167                   NaN               28014         Madrid
#
#                                   name    referralId venuePage.id
# 0                         Hotel Agumar  v-1543345600          NaN
# 1          AC Hotel by Marriott Atocha  v-1543345600    129870220
# 2  AC Hotel by Marriott Carlton Madrid  v-1543345600    182956427
# 3             Hotel TRYP Madrid Atocha  v-1543345600    505730815
# 4     Radisson Blu Hotel, Madrid Prado  v-1543345600          NaN

# %%
df.shape
# Out:
# (50, 19)

# %%
df.rename(columns={'location.postalCode':'Area', 'location.lat':'Latitude', 'location.lng':'Longitude'}, inplace=True)

# %%
df.dropna(subset=['Area'], axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df1 = df[['Area', 'name', 'Latitude', 'Longitude']]
df1
# Out:
#      Area                                     name   Latitude  Longitude
# 0   28014                             Hotel Agumar  40.406855  -3.683119
# 1   28045              AC Hotel by Marriott Atocha  40.403773  -3.689994
# 2   28045      AC Hotel by Marriott Carlton Madrid  40.405123  -3.693702
# 3   28012                 Hotel TRYP Madrid Atocha  40.411691  -3.697533
# 4   28014         Radisson Blu Hotel, Madrid Prado  40.412517  -3.694167
# 5   28012              Hotel Catalonia Atocha ****  40.411843  -3.697838
# 6   28014                        Vincci Soho Hotel  40.414773  -3.698160
# 7   28012              Hotel Catalonia Plaza Mayor  40.413180  -3.700828
# 8   28046                        Hotel Villa Magna  40.429984  -3.687964
# 9   28004                            Hotel 7 Islas  40.421292  -3.701927
# 10  28001           AC Hotel by Marriott Recoletos  40.421381  -3.689498
# 11  28001                        Hotel Vincci Soma  40.424943  -3.677994
# 12  28013            Hotel Catalonia Gran Vía ****  40.419551  -3.699064
# 13  28001                Hotel Jardín de Recoletos  40.422124  -3.689200
# 14  28014               Hotel Catalonia Las Cortes  40.414554  -3.699495
# 15  28004                    Only YOU Hotel&Lounge  40.422200  -3.695799
# 16  28014                       Hotel Urban Madrid  40.416372  -3.698679
# 17  28012                     Medium Cortezo Hotel  40.413721  -3.703601
# 18  28013                   Hotel Praktik Metropol  40.419691  -3.701709
# 19  28013                   Hotel Emperador Madrid  40.421427  -3.707880
# 20  28001                       Hotel Único Madrid  40.428560  -3.686494
# 21  28004                  Hotel Eurostars Central  40.426954  -3.698475
# 22  28012                  Hotel chic&basic Atocha  40.410325  -3.694692
# 23  28001                      Hotel Hospes Madrid  40.420445  -3.689146
# 24  28012           Hotel Catalonia Puerta del Sol  40.414012  -3.702940
# 25  28010                     Hotel Gran Versalles  40.428374  -3.697102
# 26  28013                   Hotel Europa Madrid***  40.417503  -3.703612
# 27  28013                          Hotel Mayorazgo  40.422105  -3.709476
# 28  28013           Hotel Intur Palacio San Martín  40.418571  -3.706700
# 29  28005                        Hotel Ganivet ***  40.408105  -3.710902
# 30  28010  Hotel Santo Mauro, Autograph Collection  40.430934  -3.693156
# 31  28014                    Only You Hotel Atocha  40.407161  -3.688438
# 32  28013                        Hotel Francisco I  40.417510  -3.707456
# 33  28012                Hotel Husa Paseo del Arte  40.409883  -3.693564
# 34  28013                       Hotel Opera Madrid  40.418856  -3.710226
# 35  28014                               Hotel Ritz  40.415591  -3.692439
# 36  28004                    Room Mate Óscar Hotel  40.420664  -3.699170
# 37  28013         Senator Gran Via 70 Spa Hotel 4*  40.422621  -3.709561
# 38  28013      Hotel Petit Palace Plaza del Carmen  40.418806  -3.703129
# 39  28013                          Hotel Atlántico  40.420372  -3.704764
# 40  28012                         Hotel Victoria 4  40.416237  -3.701691
# 41  28013                    Hotel Vincci Gran Via  40.422408  -3.708890
# 42  28010                    Hotel Juan de Austria  40.431893  -3.699728
# 43  28013                          Hotel Preciados  40.419705  -3.707515
# 44  28012                           Hotel Mediodia  40.408348  -3.692810
# 45  28014                           Hotel Asturias  40.416807  -3.700278
# 46  28013                    Room Mate Laura Hotel  40.418545  -3.707308

# %% [markdown]
# **Let's take the data via Foursquare API for Hotels in Barcelona downtown.**

# %%
CLIENT_ID = '2SRL1KRLKMDOPB53MA30O0BCKNEZFBPHNTAAKKYJD1RCI0IH' # your Foursquare ID
CLIENT_SECRET = '4XFUL1KQVXEFRO0V04XKXYUKKYBCAGIWWJQ1G4Y5C30EGNMH' # your Foursquare Secret
#city: Barcelona
latitude = 41.38424664
longitude = 2.17634927

VERSION = '20180604'
search_query = 'Hotel'
radius = 2000
LIMIT = 100

url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url1
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2SRL1KRLKMDOPB53MA30O0BCKNEZFBPHNTAAKKYJD1RCI0IH&client_secret=4XFUL1KQVXEFRO0V04XKXYUKKYBCAGIWWJQ1G4Y5C30EGNMH&ll=41.38424664,2.17634927&v=20180604&query=Hotel&radius=2000&limit=100'

# %%
results1 = requests.get(url1).json()

# %%
venues1 = results1['response']['venues']
dfB = json_normalize(venues1)
dfB.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id       location.address location.cc location.city  \
# 0  4bc6e78814d79521fc6866e9       Via Laietana, 30          ES     Barcelona
# 1  4dc29d9ed22dd7df9aac5483  Av. de la Catedral, 7          ES     Barcelona
# 2  4c17be58838020a1d123e361        C. Boqueria, 10          ES     Barcelona
# 3  4bf46b0194af2d7f0e953a72        Via Laietana, 3          ES     Barcelona
# 4  4c8bb638a92fa0933f399dbf    Plaça de l'Àngel 12          ES     Barcelona
#
#   location.country  location.crossStreet  location.distance  \
# 0           España  Plaça d'Antoni Maura                136
# 1           España                   NaN                 78
# 2           España                   NaN                385
# 3           España                   NaN                426
# 4           España                   NaN                186
#
#                            location.formattedAddress  \
# 0  [Via Laietana, 30 (Plaça d'Antoni Maura), 0800...
# 1  [Av. de la Catedral, 7, 08002 Barcelona Catalu...
# 2  [C. Boqueria, 10, 08002 Barcelona Cataluña, Es...
# 3  [Via Laietana, 3, 08003 Barcelona Cataluña, Es...
# 4  [Plaça de l'Àngel 12, Barcelona Cataluña, España]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 41.384969, 'lng':...     41.384969
# 1  [{'label': 'display', 'lat': 41.38489539946631...     41.384895
# 2  [{'label': 'display', 'lat': 41.38121683799184...     41.381217
# 3  [{'label': 'display', 'lat': 41.38234704347800...     41.382347
# 4  [{'label': 'display', 'lat': 41.38388613223940...     41.383886
#
#    location.lng location.postalCode location.state  \
# 0      2.177663               08003       Cataluña
# 1      2.175994               08002       Cataluña
# 2      2.174108               08002       Cataluña
# 3      2.180777               08003       Cataluña
# 4      2.178524                 NaN       Cataluña
#
#                                  name    referralId venuePage.id
# 0                 Grand Hotel Central  v-1543345941          NaN
# 1               Hotel Colon Barcelona  v-1543345941          NaN
# 2  Hotel Petit Palace Boquería Garden  v-1543345941          NaN
# 3                      Hotel Colonial  v-1543345941          NaN
# 4                         Hotel Suizo  v-1543345941          NaN

# %%
dfB.shape
# Out:
# (50, 18)

# %%
dfB.rename(columns={'location.postalCode':'Area', 'location.lat':'Latitude', 'location.lng':'Longitude'}, inplace=True)

# %%
dfB.dropna(subset=['Area'], axis=0, inplace=True)
dfB.reset_index(drop=True, inplace=True)

# %%
df2 = dfB[['Area', 'name', 'Latitude', 'Longitude']]
df2
# Out:
#      Area                                    name   Latitude  Longitude
# 0   08003                     Grand Hotel Central  41.384969   2.177663
# 1   08002                   Hotel Colon Barcelona  41.384895   2.175994
# 2   08002      Hotel Petit Palace Boquería Garden  41.381217   2.174108
# 3   08003                          Hotel Colonial  41.382347   2.180777
# 4   08001                 Hotel Catalonia Ramblas  41.385270   2.166965
# 5   08010                       Hotel Vincci Gala  41.389560   2.174757
# 6   08002                Hotel Barcelona Catedral  41.384972   2.175132
# 7   08039  Eurostars Grand Marina Hotel Barcelona  41.371508   2.181490
# 8   08002                Hotel Catalonia Catedral  41.384747   2.174455
# 9   08002                     Hotel Royal Ramblas  41.384362   2.170742
# 10  08002         Hotel Catalonia Plaza Catalunya  41.386406   2.168230
# 11  08002                      Olivia Plaza Hotel  41.386074   2.171258
# 12  08002       Hotel Catalonia Portal de l'Àngel  41.385435   2.172743
# 13  08002                Hotel Duquesa de Cardona  41.379801   2.180637
# 14  08010               El Palace Hotel Barcelona  41.391485   2.171460
# 15  08002               Hotel Serhs Rivoli Rambla  41.384191   2.171060
# 16  08010                  Hotel Indigo Barcelona  41.391328   2.170100
# 17  08002                  Hotel Catalonia Avinyó  41.381260   2.176382
# 18  08003                       K+K Hotel Picasso  41.386667   2.184064
# 19  08002                    Hotel Catalonia Port  41.378738   2.178700
# 20  08007                  NH Gran Hotel Calderón  41.389264   2.166129
# 21  08002                         Hotel Catalunya  41.385429   2.171697
# 22  08002                            Hotel Regina  41.386020   2.167945
# 23  08001                            Hotel España  41.379899   2.172996
# 24  08007       Hotel Catalonia Passeig de Gràcia  41.390191   2.169558
# 25  08010                Hotel Acta Atrium Palace  41.390954   2.170494
# 26  08004              Tryp Barcelona Apolo Hotel  41.374664   2.170726
# 27  08013                        Ayre Hotel Caspe  41.396066   2.179531
# 28  08001                            Hotel España  41.379964   2.172833
# 29  08002                        Hotel Flor Parks  41.380726   2.173853
# 30  08003                    Hotel Catalonia Born  41.389819   2.180023
# 31  08001                       Hotel San Agustín  41.380715   2.171706
# 32  08001                     Hotel Barceló Raval  41.379025   2.169729
# 33  08002                              Hotel 1898  41.383404   2.170680
# 34  08010                         Hotel NH Pódium  41.391672   2.177914
# 35  08002                            Nouvel Hotel  41.385272   2.171669
# 36  08009                    Hotel Praktik Garden  41.393767   2.171349
# 37  08001                    Hotel Medium Monegal  41.385337   2.169708
# 38  08001                             Hotel Gaudí  41.378903   2.174046
# 39  08007               Hotel Petit Palace Museum  41.388921   2.165360
# 40  08004                   Hotel Grums Barcelona  41.372915   2.171801
# 41  08001                              Hotel Lleó  41.385754   2.166527
# 42  08011                        Hotel Gran Ronda  41.383130   2.163298
# 43  08003                    Musik Boutique Hotel  41.388007   2.178391
# 44  08002                          Hotel Pulitzer  41.386245   2.168272
